# %% [markdown]
# **BBM473 Database Laboratory (Spring 2025)**
#
#
#
# Exercise 0: Introduction
# ---------------------
#
# Let us warm up!
#
# **Note: DO NOT PANIC**
# * Don't worry if you get (a) a big red-highlighted warning or (b) a note that the extension has already been loaded!  As long as your SQL commands work, it's loaded properly!
#
# * If you don't understand all the SQL queries... very soon, you will!

# %% [markdown]
# ``!pip install ipython-sql``

# %%
# !pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Using cached ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting prettytable (from ipython-sql)
#   Using cached prettytable-3.14.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: ipython in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython-sql) (8.15.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython-sql) (2.0.30)
# Requirement already satisfied: sqlparse in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython-sql) (0.5.1)
# Requirement already satisfied: six in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: ipython-genutils in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: backcall in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: exceptiongroup in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: appnope in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.1.2)
# Requirement already satisfied: wcwidth in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/omer_guler/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Using cached ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Using cached prettytable-3.14.0-py3-none-any.whl (31 kB)
# Installing collected packages: prettytable, ipython-sql
# Successfully installed ipython-sql-0.5.0 prettytable-3.14.0

# %%
# %load_ext sql

# %% [markdown]
# Please run the cell below if you get the error "KeyError: 'DEFAULT'" for the cells below.

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# !dir # or !ls depending on your OS
# Out:
# zsh:1: command not found: dir

# %% [markdown]
# Next, we'll load an SQLite database stored as a file as follows:
#
# **NOTE: We load a file below (here, "dataset_1.db", which must be in the same directory as the notebook. You'll use this file throughout the next few lectures. Make sure to download it from the webpage!!**

# %%
# %sql sqlite:///dataset_1.db

# %% [markdown]
# Lets look at one table from the US National Oceanic and Atmospheric Administration (NOAA) Rainfall dataset- `precipitation_full`- having the following schema:
#
# > * `state_code`
# > * `station_id`
# > * `year`
# > * `month`
# > * `day`
# > * `hour`
# > * `precipitation`
# > * `flag_1`
# > * `flag_2`
#
# Each tuple in this table describes one hour of rainfall (`precipitation`- in hundredths of an inch) at one station (`station_id`) in one state (`state_code`).  Note that tuples with `hour=25` record the total rainfall for that day, and that we can ignore the values of attributes `flag_1` and `flag_2` for now.
#
# Let's take a look at some sample rows of the table via SQL queries.

# %% [markdown]
# Note that you can also load an empty in-memory database using:
#
# ``%sql sqlite://``
#
# Now let's try out some queries!  (Don't worry, if you're new to SQL, we'll go over all the syntax in more depth next lecture)
#
# **`%sql` is used for single line SQL commands:**

# %%
# %%sql
# SELECT * FROM precipitation_full LIMIT 3;
# Out:
#  * sqlite:///dataset_1.db
# Done.
# [(1, 807, 2013, 9, 1, 1, None, '[', ''),
#  (1, 807, 2013, 9, 1, 25, 0, 'I', ''),
#  (1, 807, 2013, 9, 30, 24, None, ']', '')]

# %%
# %sql SELECT name FROM sqlite_master WHERE type ='table' AND name NOT LIKE 'sqlite_%';
# Out:
#  * sqlite:///dataset_1.db
# Done.
# [('precipitation_full',),
#  ('states',),
#  ('precipitation',),
#  ('A',),
#  ('B',),
#  ('streets',),
#  ('franchise',),
#  ('store',),
#  ('bagel',),
#  ('purchase',)]

# %%
# %%sql
# SELECT COUNT(*) FROM precipitation_full;
# Out:
#  * sqlite:///dataset_1.db
# Done.
# [(74251,)]

# %% [markdown]
# And **`%%sql` is used for multi-line SQL commands:**

# %%
# %%sql
# SELECT SUM(p.precipitation)
# FROM precipitation_full p, states s
# WHERE p.state_code = s.code AND s.abbrev = 'CA';
# Out:
#  * sqlite:///dataset_1.db
# Done.
# [(31982,)]

# %% [markdown]
# We can also work with the output of the queries we issue:

# %%
result = %sql SELECT * FROM states;
# Out:
#  * sqlite:///dataset_1.db
# Done.

# %%
result.keys
# Out:
# RMKeyView(['code', 'name', 'abbrev'])

# %%
# Alternative python code
for k in result.keys:
    print(k)
# Out:
# code
# name
# abbrev

# %% [markdown]
# *Note that the first row is the header row with column names!*

# %%
result[0]
# Out:
# (0, 'State', 'Abbreviation')

# %%
result[1]
# Out:
# (1, 'Alabama', 'AL')

# %%
result[1].name
# Out:
# 'Alabama'

# %% [markdown]
# Now feel free to have fun with the dataset- we'll see more of it later though!
